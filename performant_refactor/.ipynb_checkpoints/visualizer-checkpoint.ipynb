# %%
from shared_tools.make_datasets import x_train, y_train
from matplotlib import pyplot as plt
import pickle, os
from deap import gp
from functools import partial
from run_gp import get_pset

def show(a_v_pairs: list[tuple[float, float]]) -> None:
    plt.scatter([a for a, _ in a_v_pairs], [v for _, v in a_v_pairs])
    plt.show()
show(y_train)

# %%
def models(dir_path: str) -> list[gp.PrimitiveTree]:
    path = f"{dir_path}/data"
    compile = partial(gp.compile, pset=get_pset(dir_path))

    return [compile(pickle.load(open(f"{path}/{file}", 'rb'))) for file in os.listdir(path) if 'best' in file]
print()
simple_pred = models('simple_pred')[1]
predictions = [simple_pred(img) for img in x_train]
show(predictions)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 7
#       3     compile = partial(gp.compile, pset=get_pset(dir_path))
#       5     return [compile(pickle.load(open(f"{path}/{file}", 'rb'))) for file in os.listdir(path) if 'best' in file]
# ----> 7 simple_pred = models('simple_pred')[1]
#       8 predictions = [simple_pred(img) for img in x_train]
#       9 show(predictions)
#
# IndexError: list index out of range
