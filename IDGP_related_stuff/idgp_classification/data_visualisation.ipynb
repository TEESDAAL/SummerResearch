# %%
import matplotlib.pyplot as plt
from deap.tools import Logbook
from typing import Callable, TypeVar
import pickle, os

# %%
def plot(logbook: Logbook) -> None:
    gen = logbook.select("gen")

    size_avgs = logbook.chapters["size"].select("avg")

    fig, axs = plt.subplots(2, 2)
    combinations = zip(["min", "max", "avg"], ["red", "green", "blue"])

    for ax, (setting, color) in zip(axs.flat, combinations):
        ax.plot(gen, logbook.chapters["fitness"].select(setting),
                color=color, label=f"fitness_{setting}")
        ax.set_title(f"Fitness {setting}")
        ax.set(xlabel='x-label', ylabel='y-label')
    axs[1,1].plot(gen, size_avgs, color="orange")
    axs[1,1].set_title("Average Size")
    # Hide x labels and tick labels for top plots and y ticks for right plots.
    for ax in axs.flat:
        ax.set(xlabel="generations", ylabel="fitness")
        # ax.label_outer()
    axs[1,1].set(ylabel="size")
    plt.show()

# %%
from typing import Iterable

T = TypeVar('T')
def retrieve_from_files(extractor: Callable[[Logbook], T], files: Iterable[str]) -> list[T]:
    result = []
    for file_path in files:
        with open(file_path, 'rb') as file:
            result.append(extractor(pickle.load(file)))
    return result

def plot_across_all_models(model: str, extractor: Callable[[Logbook], T], title: str) -> None:
    for result in retrieve_from_files(
        extractor,
        (f"{model}/data/{name}" for name in os.listdir(f"{model}/data") if "log" in name)
    ):
             plt.plot(result)
    plt.title(title)
    plt.show()

# %%
plot_across_all_models('simple_pred', lambda l: l.chapters["fitness"].select('max'), title="minimum accuracy simple pred")
plot_across_all_models('simple_pred', lambda l: l.chapters["size"].select('avg'), title="Average size simple pred")

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plot_across_all_models('MLGP', lambda l: l.chapters["fitness"].select('max'), title="minimum accuracy simple pred")
#       2 plot_across_all_models('MLGP', lambda l: l.chapters["size"].select('avg'), title="Average size simple pred")
#
# Cell In[3], line 14, in plot_across_all_models(model, extractor, title)
#      11 def plot_across_all_models(model: str, extractor: Callable[[Logbook], T], title: str) -> None:
#      12     for result in retrieve_from_files(
#      13         extractor,
# ---> 14         (f"{model}/data/{name}" for name in os.listdir(f"{model}/data") if "log" in name)
#      15     ):
#      16              plt.plot(result)
#      17     plt.title(title)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'MLGP/data'
